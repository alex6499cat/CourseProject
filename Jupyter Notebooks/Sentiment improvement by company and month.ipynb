# %% [markdown]
# The objective is to calculate the difference in sentiment between the First Customer Tweet and the Last Customer Tweet of each conversation thread.
# Then that difference (improvement) in sentiment is summarized by company and by time (year-month).

# %%
import pandas as pd

# %%
senti_improve = pd.read_csv('thread_first_last_sentiment.csv', dtype = {'tweet_id': str})
senti_improve.head(50)
# Out:
#    tweet_id       author_id     company_name  \
# 0         2          115712       sprintcare
# 1        11      sprintcare       sprintcare
# 2        27    Ask_Spectrum     Ask_Spectrum
# 3        23          115716     Ask_Spectrum
# 4        37  VerizonSupport   VerizonSupport
# 5        50  VerizonSupport   VerizonSupport
# 6        65          115728   ChipotleTweets
# 7        73  ChipotleTweets   ChipotleTweets
# 8       160  ChipotleTweets   ChipotleTweets
# 9       179          115744   AskPlayStation
# 10      182  AskPlayStation   AskPlayStation
# 11      200          115749  marksandspencer
# 12      196          115749  marksandspencer
# 13      197          115749  marksandspencer
# 14      204          115751   MicrosoftHelps
# 15      214      ATVIAssist       ATVIAssist
# 16      236          115763       ATVIAssist
# 17      244          115767        AdobeCare
# 18      257          115768        AdobeCare
# 19      267       AdobeCare        AdobeCare
# 20      266          115768        AdobeCare
# 21      268          115768        AdobeCare
# 22      270          115770       AmazonHelp
# 23      275      AmazonHelp       AmazonHelp
# 24      284       AdobeCare        AdobeCare
# 25      299       AdobeCare        AdobeCare
# 26      301          115781        AdobeCare
# 27      303      AirbnbHelp       AirbnbHelp
# 28      322          115791      XboxSupport
# 29      365  AirAsiaSupport   AirAsiaSupport
# 30      382          115803        Morrisons
# 31      392     NikeSupport      NikeSupport
# 32      402         AskAmex          AskAmex
# 33      610          115818            Delta
# 34      613          115819        McDonalds
# 35      619          115820       AmazonHelp
# 36      625      AmazonHelp       AmazonHelp
# 37      647      AmazonHelp       AmazonHelp
# 38      655      AmazonHelp       AmazonHelp
# 39      656      AmazonHelp       AmazonHelp
# 40      666          115843       AmazonHelp
# 41      687      AmazonHelp       AmazonHelp
# 42      713          115856     AppleSupport
# 43      716    AppleSupport     AppleSupport
# 44      720    AppleSupport     AppleSupport
# 45      737    AppleSupport     AppleSupport
# 46      743    AppleSupport     AppleSupport
# 47      753    AppleSupport     AppleSupport
# 48      759    AppleSupport     AppleSupport
# 49      769          115872     Uber_Support
#
#                                               tweet_l  \
# 0                                       8|6|5|4|3|1|2
# 1                                   18|17|16|15|12|11
# 2                             29|28|24|21|22|25|26|27
# 3                                      29|28|24|21|23
# 4                                         36|34|35|37
# 5                       59|58|57|56|55|54|53|52|51|50
# 6                                            66|64|65
# 7                                         76|75|74|73
# 8                                     163|162|161|160
# 9                                         180|178|179
# 10                                    185|184|183|182
# 11                                198|194|195|199|200
# 12                                        198|194|196
# 13                                        198|194|197
# 14                                        205|203|204
# 15                            216|215|213|211|212|214
# 16                                        237|235|236
# 17                250|249|247|245|242|240|241|243|244
# 18                        253|251|252|254|255|256|257
# 19  253|251|252|254|255|256|258|259|260|261|262|26...
# 20  253|251|252|254|255|256|258|259|260|261|262|26...
# 21  253|251|252|254|255|256|258|259|260|261|262|26...
# 22                                        272|269|270
# 23                            272|269|271|273|274|275
# 24                            290|289|288|287|285|284
# 25                                    298|296|297|299
# 26                                298|296|297|300|301
# 27                                    306|305|304|303
# 28                                        323|321|322
# 29                            367|366|364|362|363|365
# 30                        378|376|377|379|380|381|382
# 31                                    395|394|393|392
# 32            406|405|404|403|399|397|398|400|401|402
# 33                                        611|609|610
# 34                                        614|612|613
# 35                                617|615|616|618|619
# 36                                    624|622|623|625
# 37                                    646|644|645|647
# 38                            652|650|651|653|654|655
# 39                                    659|658|657|656
# 40                                        667|665|666
# 41                            690|689|686|684|685|687
# 42                                        714|712|713
# 43                                    719|718|717|716
# 44                                    723|722|721|720
# 45                                    736|734|735|737
# 46            747|746|745|744|740|738|739|741|742|743
# 47                                    756|755|754|753
# 48                            765|764|763|761|760|759
# 49                                        771|768|769
#
#                                              author_l  \
# 0   115712|sprintcare|115712|sprintcare|115712|spr...
# 1   115713|sprintcare|115713|sprintcare|115713|spr...
# 2   115716|Ask_Spectrum|115716|Ask_Spectrum|115716...
# 3      115716|Ask_Spectrum|115716|Ask_Spectrum|115716
# 4         115719|VerizonSupport|115719|VerizonSupport
# 5   115723|VerizonSupport|115723|VerizonSupport|11...
# 6                        115728|ChipotleTweets|115728
# 7         115731|ChipotleTweets|115731|ChipotleTweets
# 8         115737|ChipotleTweets|115737|ChipotleTweets
# 9                        115743|AskPlayStation|115744
# 10        115745|AskPlayStation|115745|AskPlayStation
# 11  115749|marksandspencer|115749|marksandspencer|...
# 12                      115749|marksandspencer|115749
# 13                      115749|marksandspencer|115749
# 14                       115751|MicrosoftHelps|115751
# 15  115755|ATVIAssist|115755|ATVIAssist|115756|ATV...
# 16                           115763|ATVIAssist|115763
# 17  115767|AdobeCare|115767|AdobeCare|115767|Adobe...
# 18  115768|AdobeCare|115768|AdobeCare|115768|Adobe...
# 19  115768|AdobeCare|115768|AdobeCare|115768|Adobe...
# 20  115768|AdobeCare|115768|AdobeCare|115768|Adobe...
# 21  115768|AdobeCare|115768|AdobeCare|115768|Adobe...
# 22                           115770|AmazonHelp|115770
# 23  115770|AmazonHelp|115770|AmazonHelp|115770|Ama...
# 24  115776|AdobeCare|115776|AdobeCare|115775|Adobe...
# 25                  115781|AdobeCare|115781|AdobeCare
# 26           115781|AdobeCare|115781|AdobeCare|115781
# 27                115782|AirbnbHelp|115782|AirbnbHelp
# 28                          115791|XboxSupport|115791
# 29  115799|AirAsiaSupport|115799|AirAsiaSupport|11...
# 30  115803|Morrisons|115803|Morrisons|115803|Morri...
# 31              115806|NikeSupport|115806|NikeSupport
# 32  115807|AskAmex|115807|AskAmex|115807|AskAmex|1...
# 33                                115818|Delta|115818
# 34                            115819|McDonalds|115819
# 35         115820|AmazonHelp|115820|AmazonHelp|115820
# 36                115824|AmazonHelp|115824|AmazonHelp
# 37                115835|AmazonHelp|115835|AmazonHelp
# 38  115838|AmazonHelp|115838|AmazonHelp|115838|Ama...
# 39                115839|AmazonHelp|115839|AmazonHelp
# 40                           115843|AmazonHelp|115843
# 41  115849|AmazonHelp|115849|AmazonHelp|115849|Ama...
# 3          True               True           True                   Negative
# 4          True               True           True                   Negative
# 5          True               True           True                   Negative
# 6          True               True           True                    Neutral
# 7          True               True           True                    Neutral
# 8          True               True           True                    Neutral
# 9          True               True           True                    Neutral
# 10         True               True           True           Negative|Neutral
# 11         True               True           True    Neutral|Neutral|Neutral
# 12         True               True           True    Neutral|Neutral|Neutral
# 13         True               True           True    Neutral|Neutral|Neutral
# 14         True               True           True                    Neutral
# 15         True               True           True                    Neutral
# 16         True               True           True           Neutral|Positive
# 17         True               True           True                    Neutral
# 18         True               True           True            Neutral|Neutral
# 19         True               True           True            Neutral|Neutral
# 20         True               True           True            Neutral|Neutral
# 21         True               True           True            Neutral|Neutral
# 22         True               True           True                    Neutral
# 23         True               True           True                    Neutral
# 24         True               True           True            Neutral|Neutral
# 25         True               True           True  Negative|Negative|Neutral
# 26         True               True           True  Negative|Negative|Neutral
# 27         True               True           True                   Positive
# 28         True               True           True           Negative|Neutral
# 29         True               True           True                   Negative
# 30         True               True           True                   Positive
# 31         True               True           True                   Positive
# 32         True               True           True          Positive|Negative
# 33         True               True           True            Neutral|Neutral
# 34         True               True           True                   Positive
# 35         True               True           True                   Negative
# 36         True               True           True           Positive|Neutral
# 37         True               True           True           Negative|Neutral
# 38         True               True           True           Neutral|Negative
# 39         True               True           True           Positive|Neutral
# 40         True               True           True           Positive|Neutral
# 41         True               True           True   Neutral|Negative|Neutral
# 42         True               True           True            Neutral|Neutral
# 43         True               True           True                    Neutral
# 44         True               True           True                   Positive
# 45         True               True           True    Neutral|Neutral|Neutral
# 46         True               True           True            Neutral|Neutral
# 47         True               True           True                    Neutral
# 48         True               True           True            Neutral|Neutral
# 49         True               True           True           Negative|Neutral
#
#                         last_sentim_l  \
# 0                             Neutral
# 1                     Neutral|Neutral
# 2                             Neutral
# 3                            Negative
# 4                       Very positive
# 5                    Neutral|Negative
# 6                            Positive
# 7                    Neutral|Positive
# 8                   Negative|Negative
# 9                             Neutral
# 10                   Negative|Neutral
# 11  Neutral|Negative|Neutral|Negative
# 12                           Positive
# 13                           Negative
# 14                            Neutral
# 15                           Negative
# 16                            Neutral
# 17                           Positive
# 18                            Neutral
# 19                   Neutral|Negative
# 20                    Neutral|Neutral
# 21      Neutral|Neutral|Very negative
# 22                    Neutral|Neutral
# 23                            Neutral
# 24                   Neutral|Negative
# 25           Neutral|Negative|Neutral
# 26                            Neutral
# 27                    Neutral|Neutral
# 28           Neutral|Negative|Neutral
# 29                            Neutral
# 30                           Positive
# 31                            Neutral
# 32                    Neutral|Neutral
# 33                            Neutral
# 34                   Neutral|Positive
# 35                           Negative
# 36                           Negative
# 37                   Negative|Neutral
# 38            Neutral|Neutral|Neutral
# 39                    Neutral|Neutral
# 40                            Neutral
# 41                    Neutral|Neutral
# 42                            Neutral
# 43                            Neutral
# 44                            Neutral
# 45                           Negative
# 46            Neutral|Neutral|Neutral
# 47                            Neutral
# 48                   Negative|Neutral
# 49                           Negative
#
#                                      first_tweet_text  \
# 0           @sprintcare is the worst customer service
# 1    y’all lie about your “great” connection. 5 ba...
# 2   actually that's a broken link you sent me and ...
# 3   actually that's a broken link you sent me and ...
# 4   somebody from @VerizonSupport please help meee...
# 5                      is the worst ISP I’ve ever had
# 6   @ChipotleTweets @28 I don't fit in my Veggie B...
# 7   When you're the only one in costume #boorito @...
# 8   @ChipotleTweets can I dress up as myself and s...
# 9   @AskPlayStation So, what's the november ps plu...
# 10  @AskPlayStation I bought Lego Star Wars in the...
# 11  @marksandspencer y do they charge you for a me...
# 12  @marksandspencer y do they charge you for a me...
# 13  @marksandspencer y do they charge you for a me...
# 14  @MicrosoftHelps hi, having trouble making purc...
# 15  @ATVIAssist can you still pre oder ww2 on the ...
# 16  @ATVIAssist I got all of my stats reset on MWR...
# 17                         Any help here @AdobeCare?
# 18   whats going on with your app. its totally stu...
# 19   whats going on with your app. its totally stu...
# 20   whats going on with your app. its totally stu...
# 21   whats going on with your app. its totally stu...
# 22               amazonのfireTVstickが見れない crying face
# 23               amazonのfireTVstickが見れない crying face
# 24  So apparently the new version of   has this co...
# 25  @AdobeCare InDesign 13.0 is exporting all PDFs...
# 26  @AdobeCare InDesign 13.0 is exporting all PDFs...
# 27  Quand ton  ne ressemble pas à celui que tu as ...
# 28   @XboxSupport  the 5 app on Xboxes not working...
# 29  @AirAsiaSupport CAS-19708536-CB92N2 CRM:032660...
# 30  Fresh cream palmier @Morrisons bakery Bellshil...
# 31  @NikeSupport I'm new to nike+ run club app,  s...
# 32  @AskAmex Thought Amex values their customers. ...
# 33  @DELTA i booked my flight using delta amex car...
# 34  My grandma's laying #Poolside thanks to @McDon...
# 35  Way to drop the ball on customer service  so p...
# 36   also, beim Addams Family-Film in Prime sind B...
# 37  .@AmazonHelp Item has not been delivered but t...
# 38  @AmazonHelp Is it possible to prevent AMZL fro...
# 39  , it’d be nice if the book I waited 4 months f...
# 40  Anna Inspired in idea lab at school to be  pac...
# 41    @AmazonHelp  Order# 3632693-6196346. You cou...
# 42  Hey @AppleSupport and anyone else who upgraded...
# 43                      Tf is wrong with my keyboard
# 44   @AppleSupport hello are all the lines closed ...
# 45  Thank you @AppleSupport I updated my phone and...
# 46  Hola @AppleSupport necesito urgente la actuali...
# 47   MY HOME BUTTON DOESN’T WORK #IOS11 @AppleSupport
# 48  After update #ios1103 no spotify on my lock sc...
# 49   you need to correct false charges from a trip...
#
#                                       last_tweet_text
# 0       @sprintcare and how do you propose we do that
# 1   @sprintcare You gonna magically change your co...
# 2   @Ask_Spectrum I received this from your corpor...
# 3   @Ask_Spectrum The correct way to do it is via ...
# 4   @VerizonSupport I finally got someone that hel...
# 5   @VerizonSupport Don’t know, router is downstai...
# 6   @ChipotleTweets @ChipotleTweets Becky is very ...
# 7   @ChipotleTweets I had excellent service tonigh...
# 8     @ChipotleTweets Tried, didn't work. How rude :/
# 9           @AskPlayStation  Can I get help already??
# 10  @AskPlayStation It was when I would go to down...
# 11  @marksandspencer I check with the Gov office a...
# 12  @marksandspencer ou must charge at least 5p a ...
# 13  @marksandspencer aren’t require charge 4 a bag...
# 14  @MicrosoftHelps @XboxSupport Brilliant, thank ...
# 15  @ATVIAssist  I'm trying to buy the digital del...
# 16             @ATVIAssist Seth_tubbs and I am on PS4
# 17                              @AdobeCare sure thing
# 18                                      @AdobeCare ok
# 19  @AdobeCare ill just wait for the next big upda...
# 20  @AdobeCare yea ive done everything you guys to...
# 21  @AdobeCare you guys have been saying that for ...
# 22        @AmazonHelp ありがとうございます。今、電話で主人が対応していただいてます。
# 23                      @AmazonHelp こちらこそありがとうございました。
# 24  @AdobeCare  It’s intermittent for me. This fil...
# 25  @AdobeCare Here is an example of an export bef...
# 26           @AdobeCare Solved this via phone support
# 27  @AirbnbHelp I've just sent you a message with ...
# 28  @XboxSupport This is what's on my screen? Not ...
# 29                 @AirAsiaSupport Hi Yana, followed!
# 30  @Morrisons Aww, Sophie deserved winner  clappi...
# 31                        @NikeSupport Thank you nike
# 32       @AskAmex Sure. Please drop me a message now.
# 33                                     @Delta DM sent
# 34  @McDonalds My granny will be attending @ the M...
# 35  @AmazonHelp I frankly don't have the patience ...
# 36               @AmazonHelp Okay, danke für die Info
# 37  @AmazonHelp That page is useless - doesn’t all...
# 38  @AmazonHelp Already started the return. UPS ge...
# 39  @AmazonHelp Already handled, just venting. It ...
# 40         @AmazonHelp Aww your reply made her night!
# 41            @AmazonHelp Details sent. Please check.
# 42              @AppleSupport Just sent you all my DM
# 43        @AppleSupport This is what is happening...
# 44  @AppleSupport are the call centres closed for ...
# 45  @AppleSupport I have the iPhone 6s Plus and ju...
# 46      @AppleSupport Okey. Thank you!  hugging face
# 47                   @AppleSupport Yes it did, 11.0.3
# 48  @AppleSupport I can not find an option to get ...
# 49  @Uber_Support Already did that was told we req...

# %%
senti_improve.set_index('tweet_id', inplace = True)
senti_improve["first_senti_avg"] = 0
senti_improve["last_senti_avg"] = 0
senti_improve["senti_improve"] = 0
senti_improve["year_month"] = ""

# %% [markdown]
# The function below average_senti will average the sentiment of every sentence of a tweet. There may be more than one sentence per tweet, therefore more than one sentiment score per tweet. If the list is empty returns 2 = Neutral.

# %%
senti_value_order = ["Very negative", "Negative", "Neutral", "Positive", "Very positive"]

def average_senti(senti_list_text):
    if type(senti_list_text) == str:
        senti_list = senti_list_text.split("|")
        senti_totalizer = 0
        for sentiment in senti_list:
            senti_totalizer += senti_value_order.index(sentiment)
        return senti_totalizer / len(senti_list)
    else:
        return 2

# %%
first_avg_col, last_avg_col, improve_col, year_month_col = senti_improve.columns.get_indexer(["first_senti_avg","last_senti_avg","senti_improve","year_month"])
first_sentiment_col, last_sentiment_col, timestamp_col = senti_improve.columns.get_indexer(["first_sentim_l","last_sentim_l","time_l"])

for row in range(len(senti_improve)):
    first_sentiment, last_sentiment, timestamp_list = senti_improve.iloc[row,[first_sentiment_col,last_sentiment_col, timestamp_col]]
    first_average = average_senti(first_sentiment)
    last_average = average_senti(last_sentiment)
    improvement = last_average - first_average
    year_month = timestamp_list[0:7]
    senti_improve.iloc[row,[first_avg_col,last_avg_col,improve_col,year_month_col ]]= [first_average,last_average, improvement, year_month]

# %%
companies = senti_improve.groupby("company_name")
output = companies.agg({"length":"mean", "first_senti_avg":"mean", "last_senti_avg":"mean", "senti_improve":"mean", "verify_thread":"size"})

# %%
senti_improve.head()
# Out:
#                author_id    company_name                  tweet_l  \
# tweet_id
# 2                 115712      sprintcare            8|6|5|4|3|1|2
# 11            sprintcare      sprintcare        18|17|16|15|12|11
# 27          Ask_Spectrum    Ask_Spectrum  29|28|24|21|22|25|26|27
# 23                115716    Ask_Spectrum           29|28|24|21|23
# 37        VerizonSupport  VerizonSupport              36|34|35|37
#
#                                                    author_l  \
# tweet_id
# 2         115712|sprintcare|115712|sprintcare|115712|spr...
# 11        115713|sprintcare|115713|sprintcare|115713|spr...
# 27        115716|Ask_Spectrum|115716|Ask_Spectrum|115716...
# 23           115716|Ask_Spectrum|115716|Ask_Spectrum|115716
# 37              115719|VerizonSupport|115719|VerizonSupport
#
#                                             inbound_l  \
# tweet_id
# 2               True|False|True|False|True|False|True
# 11                   True|False|True|False|True|False
# 27        True|False|True|False|True|False|True|False
# 23                         True|False|True|False|True
# 37                              True|False|True|False
#
#                                                      time_l  length  \
# tweet_id
# 2         2017-10-31 21:45:10+00:00|2017-10-31 21:46:24+...       7
# 11        2017-10-31 19:56:01+00:00|2017-10-31 19:59:13+...       6
# 27        2017-10-31 22:01:35+00:00|2017-10-31 22:05:37+...       8
# 23        2017-10-31 22:01:35+00:00|2017-10-31 22:05:37+...       5
# 37        2017-10-31 22:10:46+00:00|2017-10-31 22:13:33+...       4
#
#           verify_thread  verify_time  verify_alternance  inbound_first  \
# tweet_id
# 2                  True         True               True           True
# 11                 True         True               True           True
# 27                 True         True               True           True
# 23                 True         True               True           True
# 37                 True         True               True           True
#
#                    first_sentim_l    last_sentim_l  \
# tweet_id
# 2                        Negative          Neutral
# 11        Neutral|Neutral|Neutral  Neutral|Neutral
# 27                       Negative          Neutral
# 23                       Negative         Negative
# 37                       Negative    Very positive
#
#                                            first_tweet_text  \
# tweet_id
# 2                 @sprintcare is the worst customer service
# 11         y’all lie about your “great” connection. 5 ba...
# 27        actually that's a broken link you sent me and ...
# 23        actually that's a broken link you sent me and ...
# 37        somebody from @VerizonSupport please help meee...
#
#                                             last_tweet_text  first_senti_avg  \
# tweet_id
# 2             @sprintcare and how do you propose we do that              1.0
# 11        @sprintcare You gonna magically change your co...              2.0
# 27        @Ask_Spectrum I received this from your corpor...              1.0
# 23        @Ask_Spectrum The correct way to do it is via ...              1.0
# 37        @VerizonSupport I finally got someone that hel...              1.0
#
#           last_senti_avg  senti_improve year_month
# tweet_id
# 2                    2.0            1.0    2017-10
# 11                   2.0            0.0    2017-10
# 27                   2.0            1.0    2017-10
# 23                   1.0            0.0    2017-10
# 37                   4.0            3.0    2017-10

# %%
senti_improve.to_csv(r'senti_improve_company_yearmonth.csv')

# %%
output.to_csv(r'summary.csv')

# %%
companies_months = senti_improve.groupby(["company_name","year_month"])
output = companies_months.agg({"length":"mean", "first_senti_avg":"mean", "last_senti_avg":"mean", "senti_improve":"mean", "verify_thread":"size"})

# %%
output.to_csv(r'summary month.csv')
